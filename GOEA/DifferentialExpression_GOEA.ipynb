# %% [markdown]
# # Run a Gene Ontology Enrichment Analysis (GOEA)

# %%
import sys
import pickle
print(sys.executable)
print(sys.path)
print(sys.version)
# Out:
# /home2/s418610/.conda/envs/py37_res_diffxpy/bin/python
# ['/home2/s418610/jupyter_notebooks/Invivo_neuronal_reprogramming/Cluster_with_10x/Remapped_10X_data/Harmony.4/Reprogramming_vs_Neurogenesis/POv2', '', '/cm/shared/apps/cnvkit/0.9.5/lib/python3.6/site-packages', '/cm/shared/apps/python/3.6.4-anaconda/lib', '/cm/shared/apps/jupyterkernel-matlab/0.16.1/lib/python3.6/site-packages', '/cm/shared/apps/python/2.7.x-anaconda/lib', '/home2/s418610/.conda/envs/py37_res_diffxpy/lib/python37.zip', '/home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7', '/home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/lib-dynload', '/home2/s418610/.local/lib/python3.7/site-packages', '/home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages', '/home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages/fa2-0.3.5-py3.7-linux-x86_64.egg', '/home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages/batchglm', '/home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages/diffxpy', '/home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages/IPython/extensions', '/home2/s418610/.ipython']
# 3.7.3 (default, Mar 27 2019, 22:11:17)
# [GCC 7.3.0]

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import statsmodels.api as sm

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# import scanpy as sc
# import harmonypy as hm

# %%
plt.rcParams['figure.figsize']=(8,8) #rescale figures
# sc.settings.verbosity = 3

print('numpy', np.__version__)
print('pandas', pd.__version__)
# print('scipy', scipy.__version__)
# print('sklearn', sklearn.__version__)
print('statsmodels', sm.__version__)
print('matplotlib', mpl.__version__)
print('seaborn', sns.__version__)

# sc.logging.print_versions()

# !date +%F
# Out:
# numpy 1.17.2
# pandas 0.25.2
# statsmodels 0.10.1
# matplotlib 3.1.3
# seaborn 0.9.0
# 2020-07-23

# %% [markdown]
# ## 1. Download Ontologies and Associations

# %% [markdown]
# ### 1a. Download Ontologies, if necessary

# %%
# Get http://geneontology.org/ontology/go-basic.obo
from goatools.base import download_go_basic_obo
obo_fname = download_go_basic_obo()
# Out:
#   EXISTS: go-basic.obo

# %% [markdown]
# ### 1b. Download Associations, if necessary

# %%
# Get ftp://ftp.ncbi.nlm.nih.gov/gene/DATA/gene2go.gz
from goatools.base import download_ncbi_associations
fin_gene2go = download_ncbi_associations()
# Out:
#   EXISTS: gene2go

# %% [markdown]
# ## 2. Load Ontologies, Associations and Background gene set

# %% [markdown]
# ### 2a. Load Ontologies

# %%
from goatools.obo_parser import GODag

obodag = GODag("go-basic.obo")
# Out:
# go-basic.obo: fmt(1.2) rel(2020-06-01) 47,233 GO Terms

# %% [markdown]
# ### 2b. Load Associations

# %%
from __future__ import print_function
from goatools.anno.genetogo_reader import Gene2GoReader

# %%
# Read NCBI's gene2go. Store annotations in a list of namedtuples
objanno = Gene2GoReader(fin_gene2go, taxids=[10090]) # Taxid 10090 is Mus musculus

# Get namespace2association where:
#    namespace is:
#        BP: biological_process               
#        MF: molecular_function
#        CC: cellular_component
#    assocation is a dict:
#        key: NCBI GeneID
#        value: A set of GO IDs associated with that gene
ns2assoc = objanno.get_ns2assc()

for nspc, id2gos in ns2assoc.items():
    print("{NS} {N:,} annotated mouse genes".format(NS=nspc, N=len(id2gos)))
# Out:
# HMS:0:00:05.250128 378,413 annotations READ: gene2go
# 1 taxids stored: 10090
# MF 16,873 annotated mouse genes
# BP 18,173 annotated mouse genes
# CC 19,028 annotated mouse genes

# %% [markdown]
# ### 2c. Load Background gene set
# The background is all mouse protein-codinge genes

# %%
from goatools.test_data.genes_NCBI_10090_ProteinCoding import GENEID2NT as GeneID2nt_mus
# from goatools.test_data.genes_NCBI_10090_All import GENEID2NT as GeneID2nt_mus

# %%
len(GeneID2nt_mus.keys())
# Out:
# 28212

# %% [markdown]
# ## 3. Initialize a GOEA object
# The GOEA object holds the Ontologies, Associations, and background.

# %%
from goatools.goea.go_enrichment_ns import GOEnrichmentStudyNS

goeaobj = GOEnrichmentStudyNS(
        GeneID2nt_mus.keys(), # List of mouse protein-coding genes
        ns2assoc, # geneid/GO associations
        obodag, # Ontologies
        propagate_counts = False,
        alpha = 0.05, # default significance cut-off
        methods = ['fdr_bh']) # defult multipletest correction method
# Out:
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  61% 17,108 of 28,212 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  65% 18,352 of 28,212 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  58% 16,497 of 28,212 population items found in association

# %% [markdown]
# ## 4. Read study genes
# * Gene symbols from DE analysis need to be converted to gene IDs first

# %% [markdown]
# #### Making a reference dictionary to convert symbols of my genes to gene IDs

# %%
GeneID2Symbol_dict = {}

# %%
for GeneID in list(GeneID2nt_mus.keys()):
    Symbols = []
    Symbols.append(GeneID2nt_mus[GeneID].Symbol)
    if not GeneID2nt_mus[GeneID].Aliases == '':
        for alias in GeneID2nt_mus[GeneID].Aliases.split(','):
            Symbols.append(alias.strip())
    GeneID2Symbol_dict[GeneID] = Symbols

# %% [markdown]
# ##### Example search of a gene symbol

# %%
gene_search = 'Ascl1'

# %%
for GeneID, names in GeneID2Symbol_dict.items():
    if gene_search in names:
        print(GeneID)
# Out:
# 17172

# %% [markdown]
# #### Loading my genes and convert symbols to IDs

# %%
int_out_dir = '/project/GCRB/Hon_lab/s418610/Projects/03.Invivo_neuronal_reprogramming/analysis/11.DE_repr_vs_neurog/intermediates/'

# %%
input_path = int_out_dir + 'test_list_collection_100iter'
with open(input_path, 'rb') as input_file:
 
    test_list_collection = pickle.load(input_file)

# %%
len(test_list_collection)
# Out:
# 100

# %% [markdown]
# ## 5. Run Gene Ontology Enrichment Analysis (GOEA)
# You may choose to keep all results or just the significant results. In this example, we choose to keep only the significant results.

# %%
goea_collection_experiment = []
goea_collection_public = []

# %%
# test_list_all = test_list_collection[0]
for iteration, test_list_all in enumerate(test_list_collection): 
    print('Current iteration: ', iteration, '\n')

    #### Examine genes enriched in experimental cells

    #### Remove DEGs that are common to all clusters (see DE analysis jupyter notebook)

    #### For each iteration of DE analysis, run GOEA for one time
    
    goea_experiment_up_all = []
    for cluster, test_cluster in test_list_all:
        experiment_up_genes = test_cluster.summary()[np.logical_and(test_cluster.summary()['qval'] < 1e-2, test_cluster.summary()['log2fc'] > 1)]
        geneids_study = []
        # Remove commonly differentially expressed genes (see DE analysis jupyter notebook)
        for gene_search in experiment_up_genes['gene']:
            if gene_search in ['Lars2', 'Ifi27', 'Gm42418', 'AY036118', 'Lenti-hGfa-Dlx2-IRES-GFP', 'tdTomato-WPRE-bGHpA']: # The 8's and 9's
                continue
            for GeneID, names in GeneID2Symbol_dict.items():
                if gene_search in names:
        #            print(GeneID)
                    geneids_study.append(GeneID)
                    break

        goea_results_all = goeaobj.run_study(geneids_study)
        # goea_results_sig = [r for r in goea_results_all if r.p_fdr_bh < 0.05]
        goea_experiment_up_all.append((cluster, experiment_up_genes, geneids_study, goea_results_all))


    #### Examine genes enriched in experimental cells

    #### Remove DEGs that are common to all clusters (see DE analysis jupyter notebook)

    #### For each iteration of DE analysis, run GOEA for one time

    goea_public_up_all = []
    for cluster, test_cluster in test_list_all:
        public_up_genes = test_cluster.summary()[np.logical_and(test_cluster.summary()['qval'] < 1e-2, test_cluster.summary()['log2fc'] < -1)]
        geneids_study = []
        # Remove commonly differentially expressed genes (see DE analysis jupyter notebook)
        for gene_search in public_up_genes['gene']:
            if gene_search in ['Rpl10', 'Rps27', 'Rps12', 'Rpl27', 'Rpl9']:
                continue
            for GeneID, names in GeneID2Symbol_dict.items():
                if gene_search in names:
        #            print(GeneID)
                    geneids_study.append(GeneID)
                    break

        goea_results_all = goeaobj.run_study(geneids_study)
        # goea_results_sig = [r for r in goea_results_all if r.p_fdr_bh < 0.05]
    #    goea_public_up_all.append((cluster, public_up_genes, geneids_study, goea_results_sig))
        goea_public_up_all.append((cluster, public_up_genes, geneids_study, goea_results_all)) # Store all test results, as GO terms of interest might not always be significant 
                                                                                                # in all cell types

    # len(goea_public_up_all)
    goea_collection_experiment.append((iteration, goea_experiment_up_all))
    goea_collection_public.append((iteration, goea_public_up_all))
# Out:
# Current iteration:  0
#
#
# Run BP Gene Ontology Analysis: current study set of 187 IDs ...
#  93%    174 of    187 study items found in association
# 100%    187 of    187 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    1,414 GO terms are associated with    174 of    187 study items
#   METHOD fdr_bh:
#       12 GO terms found significant (< 0.05=alpha) ( 12 enriched +   0 purified): statsmodels fdr_bh
#       84 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 187 IDs ...
#  96%    179 of    187 study items found in association
# 100%    187 of    187 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      303 GO terms are associated with    179 of    187 study items
#   METHOD fdr_bh:
#       28 GO terms found significant (< 0.05=alpha) ( 28 enriched +   0 purified): statsmodels fdr_bh
#      168 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 187 IDs ...
#  89%    167 of    187 study items found in association
# 100%    187 of    187 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      365 GO terms are associated with    167 of    187 study items
#   METHOD fdr_bh:
#       16 GO terms found significant (< 0.05=alpha) ( 16 enriched +   0 purified): statsmodels fdr_bh
#      132 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 723 IDs ...
#  92%    664 of    723 study items found in association
# 100%    723 of    723 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    3,336 GO terms are associated with    664 of    723 study items
#   METHOD fdr_bh:
#       84 GO terms found significant (< 0.05=alpha) ( 82 enriched +   2 purified): statsmodels fdr_bh
#      447 study items associated with significant GO IDs (enriched)
#       16 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 723 IDs ...
#  96%    693 of    723 study items found in association
# 100%    723 of    723 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      532 GO terms are associated with    693 of    723 study items
#   METHOD fdr_bh:
#       69 GO terms found significant (< 0.05=alpha) ( 69 enriched +   0 purified): statsmodels fdr_bh
#      684 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 723 IDs ...
#  89%    641 of    723 study items found in association
# 100%    723 of    723 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      944 GO terms are associated with    641 of    723 study items
#   METHOD fdr_bh:
#       65 GO terms found significant (< 0.05=alpha) ( 64 enriched +   1 purified): statsmodels fdr_bh
#      562 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 2089 IDs ...
#  89%  1,861 of  2,087 study items found in association
# 100%  2,087 of  2,089 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    5,334 GO terms are associated with  1,861 of  2,087 study items
#   METHOD fdr_bh:
#      191 GO terms found significant (< 0.05=alpha) (187 enriched +   4 purified): statsmodels fdr_bh
#    1,406 study items associated with significant GO IDs (enriched)
#       27 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 2089 IDs ...
#  94%  1,961 of  2,087 study items found in association
# 100%  2,087 of  2,089 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      987 GO terms are associated with  1,961 of  2,087 study items
#   METHOD fdr_bh:
#      143 GO terms found significant (< 0.05=alpha) (140 enriched +   3 purified): statsmodels fdr_bh
#    1,921 study items associated with significant GO IDs (enriched)
#      162 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 2089 IDs ...
#  84%  1,751 of  2,087 study items found in association
# 100%  2,087 of  2,089 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#    1,546 GO terms are associated with  1,751 of  2,087 study items
#   METHOD fdr_bh:
#      122 GO terms found significant (< 0.05=alpha) (117 enriched +   5 purified): statsmodels fdr_bh
#    1,571 study items associated with significant GO IDs (enriched)
#       10 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 437 IDs ...
#  91%    399 of    437 study items found in association
# 100%    437 of    437 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    2,384 GO terms are associated with    399 of    437 study items
#   METHOD fdr_bh:
#       61 GO terms found significant (< 0.05=alpha) ( 59 enriched +   2 purified): statsmodels fdr_bh
#      237 study items associated with significant GO IDs (enriched)
#        4 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 437 IDs ...
#  95%    417 of    437 study items found in association
# 100%    437 of    437 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      464 GO terms are associated with    417 of    437 study items
#   METHOD fdr_bh:
#       43 GO terms found significant (< 0.05=alpha) ( 43 enriched +   0 purified): statsmodels fdr_bh
#      402 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 437 IDs ...
#  86%    374 of    437 study items found in association
# 100%    437 of    437 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      617 GO terms are associated with    374 of    437 study items
#   METHOD fdr_bh:
#       36 GO terms found significant (< 0.05=alpha) ( 35 enriched +   1 purified): statsmodels fdr_bh
#      314 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 306 IDs ...
#  92%    281 of    306 study items found in association
# 100%    306 of    306 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    1,861 GO terms are associated with    281 of    306 study items
#   METHOD fdr_bh:
#       22 GO terms found significant (< 0.05=alpha) ( 21 enriched +   1 purified): statsmodels fdr_bh
#      136 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 306 IDs ...
#  96%    293 of    306 study items found in association
# 100%    306 of    306 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      410 GO terms are associated with    293 of    306 study items
#   METHOD fdr_bh:
#       32 GO terms found significant (< 0.05=alpha) ( 32 enriched +   0 purified): statsmodels fdr_bh
#      280 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 306 IDs ...
#  87%    265 of    306 study items found in association
# 100%    306 of    306 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      494 GO terms are associated with    265 of    306 study items
#   METHOD fdr_bh:
#       31 GO terms found significant (< 0.05=alpha) ( 30 enriched +   1 purified): statsmodels fdr_bh
#      216 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 164 IDs ...
#  91%    150 of    164 study items found in association
# 100%    164 of    164 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    1,326 GO terms are associated with    150 of    164 study items
#   METHOD fdr_bh:
#       10 GO terms found significant (< 0.05=alpha) ( 10 enriched +   0 purified): statsmodels fdr_bh
#       57 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 164 IDs ...
#  96%    157 of    164 study items found in association
# 100%    164 of    164 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      293 GO terms are associated with    157 of    164 study items
#   METHOD fdr_bh:
#       23 GO terms found significant (< 0.05=alpha) ( 23 enriched +   0 purified): statsmodels fdr_bh
#      149 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 164 IDs ...
#  90%    147 of    164 study items found in association
# 100%    164 of    164 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      377 GO terms are associated with    147 of    164 study items
#   METHOD fdr_bh:
#       17 GO terms found significant (< 0.05=alpha) ( 17 enriched +   0 purified): statsmodels fdr_bh
#      119 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 1265 IDs ...
#  90%  1,134 of  1,265 study items found in association
# 100%  1,265 of  1,265 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    4,329 GO terms are associated with  1,134 of  1,265 study items
#   METHOD fdr_bh:
#      131 GO terms found significant (< 0.05=alpha) (129 enriched +   2 purified): statsmodels fdr_bh
#      794 study items associated with significant GO IDs (enriched)
#       19 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 1265 IDs ...
#  95%  1,198 of  1,265 study items found in association
# 100%  1,265 of  1,265 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      781 GO terms are associated with  1,198 of  1,265 study items
#   METHOD fdr_bh:
#      101 GO terms found significant (< 0.05=alpha) (100 enriched +   1 purified): statsmodels fdr_bh
#    1,179 study items associated with significant GO IDs (enriched)
#      197 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 1265 IDs ...
#  86%  1,089 of  1,265 study items found in association
# 100%  1,265 of  1,265 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#    1,151 GO terms are associated with  1,089 of  1,265 study items
#   METHOD fdr_bh:
#      105 GO terms found significant (< 0.05=alpha) (100 enriched +   5 purified): statsmodels fdr_bh
#      995 study items associated with significant GO IDs (enriched)
#        6 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 559 IDs ...
#  91%    505 of    558 study items found in association
# 100%    558 of    559 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    2,728 GO terms are associated with    505 of    558 study items
#   METHOD fdr_bh:
#       30 GO terms found significant (< 0.05=alpha) ( 29 enriched +   1 purified): statsmodels fdr_bh
#      255 study items associated with significant GO IDs (enriched)
#        2 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 559 IDs ...
#  94%    527 of    558 study items found in association
# 100%    558 of    559 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      435 GO terms are associated with    527 of    558 study items
#   METHOD fdr_bh:
#       69 GO terms found significant (< 0.05=alpha) ( 69 enriched +   0 purified): statsmodels fdr_bh
#      517 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 559 IDs ...
#  88%    489 of    558 study items found in association
# 100%    558 of    559 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      835 GO terms are associated with    489 of    558 study items
#   METHOD fdr_bh:
#       16 GO terms found significant (< 0.05=alpha) ( 15 enriched +   1 purified): statsmodels fdr_bh
#      358 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 683 IDs ...
#  92%    627 of    683 study items found in association
# 100%    683 of    683 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    3,165 GO terms are associated with    627 of    683 study items
#   METHOD fdr_bh:
#       59 GO terms found significant (< 0.05=alpha) ( 58 enriched +   1 purified): statsmodels fdr_bh
#      442 study items associated with significant GO IDs (enriched)
#        1 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 683 IDs ...
#  95%    651 of    683 study items found in association
# 100%    683 of    683 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      531 GO terms are associated with    651 of    683 study items
#   METHOD fdr_bh:
#       78 GO terms found significant (< 0.05=alpha) ( 78 enriched +   0 purified): statsmodels fdr_bh
#      642 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 683 IDs ...
#  89%    609 of    683 study items found in association
# 100%    683 of    683 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      984 GO terms are associated with    609 of    683 study items
#   METHOD fdr_bh:
#       41 GO terms found significant (< 0.05=alpha) ( 40 enriched +   1 purified): statsmodels fdr_bh
#      503 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 34 IDs ...
#  88%     30 of     34 study items found in association
# 100%     34 of     34 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#      255 GO terms are associated with     30 of     34 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#        3 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 34 IDs ...
#  94%     32 of     34 study items found in association
# 100%     34 of     34 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      100 GO terms are associated with     32 of     34 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#        9 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 34 IDs ...
#  88%     30 of     34 study items found in association
# 100%     34 of     34 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      105 GO terms are associated with     30 of     34 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 406 IDs ...
#  87%    351 of    405 study items found in association
# 100%    405 of    406 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    2,022 GO terms are associated with    351 of    405 study items
#   METHOD fdr_bh:
#       34 GO terms found significant (< 0.05=alpha) ( 32 enriched +   2 purified): statsmodels fdr_bh
#      182 study items associated with significant GO IDs (enriched)
#        4 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 406 IDs ...
#  94%    379 of    405 study items found in association
# 100%    405 of    406 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      404 GO terms are associated with    379 of    405 study items
#   METHOD fdr_bh:
#       31 GO terms found significant (< 0.05=alpha) ( 31 enriched +   0 purified): statsmodels fdr_bh
#      358 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 406 IDs ...
#  82%    334 of    405 study items found in association
# 100%    405 of    406 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      552 GO terms are associated with    334 of    405 study items
#   METHOD fdr_bh:
#        9 GO terms found significant (< 0.05=alpha) (  8 enriched +   1 purified): statsmodels fdr_bh
#      208 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 111 IDs ...
#  89%     99 of    111 study items found in association
# 100%    111 of    111 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    1,000 GO terms are associated with     99 of    111 study items
#   METHOD fdr_bh:
#       42 GO terms found significant (< 0.05=alpha) ( 42 enriched +   0 purified): statsmodels fdr_bh
#       58 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 111 IDs ...
#  94%    104 of    111 study items found in association
# 100%    111 of    111 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      178 GO terms are associated with    104 of    111 study items
#   METHOD fdr_bh:
#        5 GO terms found significant (< 0.05=alpha) (  5 enriched +   0 purified): statsmodels fdr_bh
#       15 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 111 IDs ...
#  93%    103 of    111 study items found in association
# 100%    111 of    111 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      243 GO terms are associated with    103 of    111 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.05=alpha) (  6 enriched +   0 purified): statsmodels fdr_bh
#       63 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 178 IDs ...
#  90%    160 of    178 study items found in association
# 100%    178 of    178 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    1,150 GO terms are associated with    160 of    178 study items
#   METHOD fdr_bh:
#       16 GO terms found significant (< 0.05=alpha) ( 16 enriched +   0 purified): statsmodels fdr_bh
#       61 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 178 IDs ...
#  93%    166 of    178 study items found in association
# 100%    178 of    178 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      227 GO terms are associated with    166 of    178 study items
#   METHOD fdr_bh:
#        9 GO terms found significant (< 0.05=alpha) (  9 enriched +   0 purified): statsmodels fdr_bh
#      120 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 178 IDs ...
#  88%    157 of    178 study items found in association
# 100%    178 of    178 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      312 GO terms are associated with    157 of    178 study items
#   METHOD fdr_bh:
#        4 GO terms found significant (< 0.05=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
#       81 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 22 IDs ...
#  86%     19 of     22 study items found in association
# 100%     22 of     22 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#      243 GO terms are associated with     19 of     22 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 22 IDs ...
#  86%     19 of     22 study items found in association
# 100%     22 of     22 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#       67 GO terms are associated with     19 of     22 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 22 IDs ...
#  91%     20 of     22 study items found in association
# 100%     22 of     22 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#       89 GO terms are associated with     20 of     22 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 15 IDs ...
# 100%     15 of     15 study items found in association
# 100%     15 of     15 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#      216 GO terms are associated with     15 of     15 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 15 IDs ...
#  93%     14 of     15 study items found in association
# 100%     15 of     15 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#       78 GO terms are associated with     14 of     15 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 15 IDs ...
#  93%     14 of     15 study items found in association
# 100%     15 of     15 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#       65 GO terms are associated with     14 of     15 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 49 IDs ...
#  84%     41 of     49 study items found in association
# 100%     49 of     49 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#      448 GO terms are associated with     41 of     49 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#        5 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 49 IDs ...
#  92%     45 of     49 study items found in association
# 100%     49 of     49 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#       91 GO terms are associated with     45 of     49 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 49 IDs ...
#  86%     42 of     49 study items found in association
# 100%     49 of     49 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      133 GO terms are associated with     42 of     49 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 915 IDs ...
#  89%    816 of    914 study items found in association
# 100%    914 of    915 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    3,264 GO terms are associated with    816 of    914 study items
#   METHOD fdr_bh:
#       35 GO terms found significant (< 0.05=alpha) ( 33 enriched +   2 purified): statsmodels fdr_bh
#      373 study items associated with significant GO IDs (enriched)
#        8 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 915 IDs ...
#  93%    850 of    914 study items found in association
# 100%    914 of    915 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      679 GO terms are associated with    850 of    914 study items
#   METHOD fdr_bh:
#       49 GO terms found significant (< 0.05=alpha) ( 49 enriched +   0 purified): statsmodels fdr_bh
#      811 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 915 IDs ...
#  84%    768 of    914 study items found in association
# 100%    914 of    915 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      917 GO terms are associated with    768 of    914 study items
#   METHOD fdr_bh:
#       29 GO terms found significant (< 0.05=alpha) ( 28 enriched +   1 purified): statsmodels fdr_bh
#      625 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 737 IDs ...
#  92%    672 of    733 study items found in association
#  99%    733 of    737 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    2,814 GO terms are associated with    672 of    733 study items
#   METHOD fdr_bh:
#       82 GO terms found significant (< 0.05=alpha) ( 80 enriched +   2 purified): statsmodels fdr_bh
#      444 study items associated with significant GO IDs (enriched)
#        7 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 737 IDs ...
#  95%    696 of    733 study items found in association
#  99%    733 of    737 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      661 GO terms are associated with    696 of    733 study items
#   METHOD fdr_bh:
#      112 GO terms found significant (< 0.05=alpha) (110 enriched +   2 purified): statsmodels fdr_bh
#      643 study items associated with significant GO IDs (enriched)
#       82 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 737 IDs ...
#  87%    635 of    733 study items found in association
#  99%    733 of    737 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      795 GO terms are associated with    635 of    733 study items
#   METHOD fdr_bh:
#       50 GO terms found significant (< 0.05=alpha) ( 48 enriched +   2 purified): statsmodels fdr_bh
#      514 study items associated with significant GO IDs (enriched)
#        2 study items associated with significant GO IDs (purified)
# Current iteration:  1
#
#
# Run BP Gene Ontology Analysis: current study set of 267 IDs ...
#  93%    249 of    267 study items found in association
# 100%    267 of    267 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    1,694 GO terms are associated with    249 of    267 study items
#   METHOD fdr_bh:
#       13 GO terms found significant (< 0.05=alpha) ( 12 enriched +   1 purified): statsmodels fdr_bh
#       99 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 267 IDs ...
#  97%    258 of    267 study items found in association
# 100%    267 of    267 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      396 GO terms are associated with    258 of    267 study items
#   METHOD fdr_bh:
#       38 GO terms found significant (< 0.05=alpha) ( 38 enriched +   0 purified): statsmodels fdr_bh
#      249 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 267 IDs ...
#  90%    241 of    267 study items found in association
# 100%    267 of    267 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      502 GO terms are associated with    241 of    267 study items
#   METHOD fdr_bh:
#       17 GO terms found significant (< 0.05=alpha) ( 16 enriched +   1 purified): statsmodels fdr_bh
#      188 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 717 IDs ...
#  92%    658 of    717 study items found in association
# 100%    717 of    717 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    3,256 GO terms are associated with    658 of    717 study items
#   METHOD fdr_bh:
#       92 GO terms found significant (< 0.05=alpha) ( 90 enriched +   2 purified): statsmodels fdr_bh
#      420 study items associated with significant GO IDs (enriched)
#       12 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 717 IDs ...
#  97%    693 of    717 study items found in association
# 100%    717 of    717 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      555 GO terms are associated with    693 of    717 study items
#   METHOD fdr_bh:
#       77 GO terms found significant (< 0.05=alpha) ( 77 enriched +   0 purified): statsmodels fdr_bh
#      687 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 717 IDs ...
#  88%    634 of    717 study items found in association
# 100%    717 of    717 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      942 GO terms are associated with    634 of    717 study items
#   METHOD fdr_bh:
#       59 GO terms found significant (< 0.05=alpha) ( 58 enriched +   1 purified): statsmodels fdr_bh
#      549 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 2599 IDs ...
#  89%  2,319 of  2,593 study items found in association
# 100%  2,593 of  2,599 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    5,963 GO terms are associated with  2,319 of  2,593 study items
#   METHOD fdr_bh:
#      321 GO terms found significant (< 0.05=alpha) (317 enriched +   4 purified): statsmodels fdr_bh
#    1,895 study items associated with significant GO IDs (enriched)
#       29 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 2599 IDs ...
#  94%  2,449 of  2,593 study items found in association
# 100%  2,593 of  2,599 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#    1,090 GO terms are associated with  2,449 of  2,593 study items
#   METHOD fdr_bh:
#      181 GO terms found significant (< 0.05=alpha) (176 enriched +   5 purified): statsmodels fdr_bh
#    2,405 study items associated with significant GO IDs (enriched)
#      555 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 2599 IDs ...
#  84%  2,171 of  2,593 study items found in association
# 100%  2,593 of  2,599 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#    1,712 GO terms are associated with  2,171 of  2,593 study items
#   METHOD fdr_bh:
#      155 GO terms found significant (< 0.05=alpha) (147 enriched +   8 purified): statsmodels fdr_bh
#    1,968 study items associated with significant GO IDs (enriched)
#       31 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 429 IDs ...
#  88%    376 of    429 study items found in association
# 100%    429 of    429 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    2,393 GO terms are associated with    376 of    429 study items
#   METHOD fdr_bh:
#       65 GO terms found significant (< 0.05=alpha) ( 63 enriched +   2 purified): statsmodels fdr_bh
#      232 study items associated with significant GO IDs (enriched)
#        7 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 429 IDs ...
#  93%    401 of    429 study items found in association
# 100%    429 of    429 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      440 GO terms are associated with    401 of    429 study items
#   METHOD fdr_bh:
#       48 GO terms found significant (< 0.05=alpha) ( 48 enriched +   0 purified): statsmodels fdr_bh
#      378 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 429 IDs ...
#  86%    369 of    429 study items found in association
# 100%    429 of    429 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      612 GO terms are associated with    369 of    429 study items
#   METHOD fdr_bh:
#       36 GO terms found significant (< 0.05=alpha) ( 35 enriched +   1 purified): statsmodels fdr_bh
#      305 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 117 IDs ...
#  91%    107 of    117 study items found in association
# 100%    117 of    117 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#      950 GO terms are associated with    107 of    117 study items
#   METHOD fdr_bh:
#        4 GO terms found significant (< 0.05=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
#       24 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 117 IDs ...
#  97%    113 of    117 study items found in association
# 100%    117 of    117 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      218 GO terms are associated with    113 of    117 study items
#   METHOD fdr_bh:
#        4 GO terms found significant (< 0.05=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
#       84 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 117 IDs ...
#  87%    102 of    117 study items found in association
# 100%    117 of    117 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      285 GO terms are associated with    102 of    117 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#       54 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 190 IDs ...
#  91%    173 of    190 study items found in association
# 100%    190 of    190 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    1,432 GO terms are associated with    173 of    190 study items
#   METHOD fdr_bh:
#       12 GO terms found significant (< 0.05=alpha) ( 12 enriched +   0 purified): statsmodels fdr_bh
#       74 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 190 IDs ...
#  96%    183 of    190 study items found in association
# 100%    190 of    190 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      316 GO terms are associated with    183 of    190 study items
#   METHOD fdr_bh:
#       38 GO terms found significant (< 0.05=alpha) ( 38 enriched +   0 purified): statsmodels fdr_bh
#      177 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 190 IDs ...
#  88%    167 of    190 study items found in association
# 100%    190 of    190 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      418 GO terms are associated with    167 of    190 study items
#   METHOD fdr_bh:
#       12 GO terms found significant (< 0.05=alpha) ( 12 enriched +   0 purified): statsmodels fdr_bh
#      129 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 1166 IDs ...
#  90%  1,044 of  1,165 study items found in association
# 100%  1,165 of  1,166 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    4,064 GO terms are associated with  1,044 of  1,165 study items
#   METHOD fdr_bh:
#      111 GO terms found significant (< 0.05=alpha) (109 enriched +   2 purified): statsmodels fdr_bh
#      728 study items associated with significant GO IDs (enriched)
#       13 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 1166 IDs ...
#  95%  1,103 of  1,165 study items found in association
# 100%  1,165 of  1,166 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      751 GO terms are associated with  1,103 of  1,165 study items
#   METHOD fdr_bh:
#      100 GO terms found significant (< 0.05=alpha) (100 enriched +   0 purified): statsmodels fdr_bh
#    1,077 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 1166 IDs ...
#  85%    995 of  1,165 study items found in association
# 100%  1,165 of  1,166 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#    1,129 GO terms are associated with    995 of  1,165 study items
#   METHOD fdr_bh:
#       78 GO terms found significant (< 0.05=alpha) ( 76 enriched +   2 purified): statsmodels fdr_bh
#      872 study items associated with significant GO IDs (enriched)
#        5 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 640 IDs ...
#  91%    583 of    640 study items found in association
# 100%    640 of    640 study items found in population(28212)
# ...
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#    1,297 GO terms are associated with  1,336 of  1,550 study items
#   METHOD fdr_bh:
#      125 GO terms found significant (< 0.05=alpha) (122 enriched +   3 purified): statsmodels fdr_bh
#    1,235 study items associated with significant GO IDs (enriched)
#        6 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 613 IDs ...
#  93%    567 of    612 study items found in association
# 100%    612 of    613 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    2,825 GO terms are associated with    567 of    612 study items
#   METHOD fdr_bh:
#       30 GO terms found significant (< 0.05=alpha) ( 29 enriched +   1 purified): statsmodels fdr_bh
#      257 study items associated with significant GO IDs (enriched)
#        1 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 613 IDs ...
#  95%    582 of    612 study items found in association
# 100%    612 of    613 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      462 GO terms are associated with    582 of    612 study items
#   METHOD fdr_bh:
#       68 GO terms found significant (< 0.05=alpha) ( 68 enriched +   0 purified): statsmodels fdr_bh
#      577 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 613 IDs ...
#  89%    545 of    612 study items found in association
# 100%    612 of    613 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      900 GO terms are associated with    545 of    612 study items
#   METHOD fdr_bh:
#       26 GO terms found significant (< 0.05=alpha) ( 25 enriched +   1 purified): statsmodels fdr_bh
#      424 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 659 IDs ...
#  93%    611 of    659 study items found in association
# 100%    659 of    659 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    3,043 GO terms are associated with    611 of    659 study items
#   METHOD fdr_bh:
#       45 GO terms found significant (< 0.05=alpha) ( 44 enriched +   1 purified): statsmodels fdr_bh
#      355 study items associated with significant GO IDs (enriched)
#        3 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 659 IDs ...
#  95%    629 of    659 study items found in association
# 100%    659 of    659 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      511 GO terms are associated with    629 of    659 study items
#   METHOD fdr_bh:
#       84 GO terms found significant (< 0.05=alpha) ( 84 enriched +   0 purified): statsmodels fdr_bh
#      622 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 659 IDs ...
#  89%    589 of    659 study items found in association
# 100%    659 of    659 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      976 GO terms are associated with    589 of    659 study items
#   METHOD fdr_bh:
#       29 GO terms found significant (< 0.05=alpha) ( 28 enriched +   1 purified): statsmodels fdr_bh
#      484 study items associated with significant GO IDs (enriched)
#        1 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 37 IDs ...
#  95%     35 of     37 study items found in association
# 100%     37 of     37 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#      402 GO terms are associated with     35 of     37 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#        8 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 37 IDs ...
# 100%     37 of     37 study items found in association
# 100%     37 of     37 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      116 GO terms are associated with     37 of     37 study items
#   METHOD fdr_bh:
#        7 GO terms found significant (< 0.05=alpha) (  7 enriched +   0 purified): statsmodels fdr_bh
#       28 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 37 IDs ...
#  92%     34 of     37 study items found in association
# 100%     37 of     37 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      104 GO terms are associated with     34 of     37 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 422 IDs ...
#  89%    374 of    422 study items found in association
# 100%    422 of    422 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    2,146 GO terms are associated with    374 of    422 study items
#   METHOD fdr_bh:
#       34 GO terms found significant (< 0.05=alpha) ( 32 enriched +   2 purified): statsmodels fdr_bh
#      203 study items associated with significant GO IDs (enriched)
#        6 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 422 IDs ...
#  94%    395 of    422 study items found in association
# 100%    422 of    422 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      420 GO terms are associated with    395 of    422 study items
#   METHOD fdr_bh:
#       20 GO terms found significant (< 0.05=alpha) ( 20 enriched +   0 purified): statsmodels fdr_bh
#      329 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 422 IDs ...
#  85%    358 of    422 study items found in association
# 100%    422 of    422 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      535 GO terms are associated with    358 of    422 study items
#   METHOD fdr_bh:
#       14 GO terms found significant (< 0.05=alpha) ( 13 enriched +   1 purified): statsmodels fdr_bh
#      233 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 124 IDs ...
#  88%    109 of    124 study items found in association
# 100%    124 of    124 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    1,054 GO terms are associated with    109 of    124 study items
#   METHOD fdr_bh:
#       50 GO terms found significant (< 0.05=alpha) ( 50 enriched +   0 purified): statsmodels fdr_bh
#       65 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 124 IDs ...
#  93%    115 of    124 study items found in association
# 100%    124 of    124 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      181 GO terms are associated with    115 of    124 study items
#   METHOD fdr_bh:
#        7 GO terms found significant (< 0.05=alpha) (  7 enriched +   0 purified): statsmodels fdr_bh
#       64 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 124 IDs ...
#  88%    109 of    124 study items found in association
# 100%    124 of    124 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      251 GO terms are associated with    109 of    124 study items
#   METHOD fdr_bh:
#        4 GO terms found significant (< 0.05=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
#       59 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 161 IDs ...
#  91%    147 of    161 study items found in association
# 100%    161 of    161 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#    1,101 GO terms are associated with    147 of    161 study items
#   METHOD fdr_bh:
#       14 GO terms found significant (< 0.05=alpha) ( 14 enriched +   0 purified): statsmodels fdr_bh
#       59 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 161 IDs ...
#  94%    152 of    161 study items found in association
# 100%    161 of    161 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#      225 GO terms are associated with    152 of    161 study items
#   METHOD fdr_bh:
#       11 GO terms found significant (< 0.05=alpha) ( 11 enriched +   0 purified): statsmodels fdr_bh
#      141 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 161 IDs ...
#  92%    148 of    161 study items found in association
# 100%    161 of    161 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      302 GO terms are associated with    148 of    161 study items
#   METHOD fdr_bh:
#        3 GO terms found significant (< 0.05=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#       80 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 34 IDs ...
#  91%     31 of     34 study items found in association
# 100%     34 of     34 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#      354 GO terms are associated with     31 of     34 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 34 IDs ...
#  94%     32 of     34 study items found in association
# 100%     34 of     34 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#       98 GO terms are associated with     32 of     34 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.05=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#        8 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 34 IDs ...
#  85%     29 of     34 study items found in association
# 100%     34 of     34 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#      130 GO terms are associated with     29 of     34 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 16 IDs ...
#  81%     13 of     16 study items found in association
# 100%     16 of     16 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats
#   12,420 GO terms are associated with 17,108 of 28,212 population items
#      122 GO terms are associated with     13 of     16 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 16 IDs ...
#  88%     14 of     16 study items found in association
# 100%     16 of     16 study items found in population(28212)
# Calculating 1,751 uncorrected p-values using fisher_scipy_stats
#    1,751 GO terms are associated with 18,352 of 28,212 population items
#       64 GO terms are associated with     14 of     16 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 16 IDs ...
#  94%     15 of     16 study items found in association
# 100%     16 of     16 study items found in population(28212)
# Calculating 4,179 uncorrected p-values using fisher_scipy_stats
#    4,179 GO terms are associated with 16,497 of 28,212 population items
#       58 GO terms are associated with     15 of     16 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 56 IDs ...
#  86%     48 of     56 study items found in association
# 100%     56 of     56 study items found in population(28212)
# Calculating 12,420 uncorrected p-values using fisher_scipy_stats

# %%
len(goea_collection_experiment)
# Out:
# 100

# %%
len(goea_collection_public)
# Out:
# 100

# %% [markdown]
# ## 6. Plot enriched GO terms of interest as a function of reprogramming progression

# %% [markdown]
# #### Extracting results

# %%
goea_DF_collection_public = []
for iteration, goea_public_up_all in goea_collection_public:

    goea_DF_list_public = []
    for cluster, _, _, goea_results_sig in goea_public_up_all:

        goID = []
        goName = []
        goNamespace = []
        goEnrichment = []
        goAdjP = []
        study_count = []
        study_n = []
        pop_count = []
        pop_n = []
        for goea_result in goea_results_sig:
            goID.append(goea_result.goterm.id)
            goName.append(goea_result.goterm.name)
            goNamespace.append(goea_result.goterm.namespace)
            goEnrichment.append(goea_result.enrichment)
            goAdjP.append(goea_result.p_fdr_bh)
            study_count.append(goea_result.study_count)
            study_n.append(goea_result.study_n)
            pop_count.append(goea_result.pop_count)
            pop_n.append(goea_result.pop_n)

        goea_summary = pd.DataFrame(data={'goID': goID,
                                         'goName': goName, 
                                         'goNamespace': goNamespace, 
                                         'goEnrichment': goEnrichment, 
                                         'goAdjP': goAdjP, 
                                         'study_count': study_count, 
                                         'study_n': study_n, 
                                         'pop_count': pop_count, 
                                         'pop_n': pop_n})

        # goea_summary.sort_values(by='goAdjP', ascending=True, inplace=True)

        # goea_summary = goea_summary[goea_summary['goEnrichment']=='e']

        goea_summary_MF = goea_summary[goea_summary['goNamespace']=='molecular_function']
        goea_summary_BP = goea_summary[goea_summary['goNamespace']=='biological_process']
        goea_summary_CC = goea_summary[goea_summary['goNamespace']=='cellular_component']

        goea_DF_list_public.append((cluster, goea_summary_MF, goea_summary_BP, goea_summary_CC))
        
    goea_DF_collection_public.append((iteration, goea_DF_list_public))

# %%
len(goea_DF_collection_public)
# Out:
# 100

# %%
goea_DF_collection_experiment = []
for iteration, goea_experiment_up_all in goea_collection_experiment:

    goea_DF_list_experiment = []
    for cluster, _, _, goea_results_sig in goea_experiment_up_all:

        goID = []
        goName = []
        goNamespace = []
        goEnrichment = []
        goAdjP = []
        study_count = []
        study_n = []
        pop_count = []
        pop_n = []
        for goea_result in goea_results_sig:
            goID.append(goea_result.goterm.id)
            goName.append(goea_result.goterm.name)
            goNamespace.append(goea_result.goterm.namespace)
            goEnrichment.append(goea_result.enrichment)
            goAdjP.append(goea_result.p_fdr_bh)
            study_count.append(goea_result.study_count)
            study_n.append(goea_result.study_n)
            pop_count.append(goea_result.pop_count)
            pop_n.append(goea_result.pop_n)

        goea_summary = pd.DataFrame(data={'goID': goID,
                                         'goName': goName, 
                                         'goNamespace': goNamespace, 
                                         'goEnrichment': goEnrichment, 
                                         'goAdjP': goAdjP, 
                                         'study_count': study_count, 
                                         'study_n': study_n, 
                                         'pop_count': pop_count, 
                                         'pop_n': pop_n})

        # goea_summary.sort_values(by='goAdjP', ascending=True, inplace=True)

        # goea_summary = goea_summary[goea_summary['goEnrichment']=='e']

        goea_summary_MF = goea_summary[goea_summary['goNamespace']=='molecular_function']
        goea_summary_BP = goea_summary[goea_summary['goNamespace']=='biological_process']
        goea_summary_CC = goea_summary[goea_summary['goNamespace']=='cellular_component']

        goea_DF_list_experiment.append((cluster, goea_summary_MF, goea_summary_BP, goea_summary_CC))
        
    goea_DF_collection_experiment.append((iteration, goea_DF_list_experiment))

# %%
len(goea_DF_collection_experiment)
# Out:
# 100

# %% [markdown]
# ##### Write and read data

# %%
int_out_dir = '/project/GCRB/Hon_lab/s418610/Projects/03.Invivo_neuronal_reprogramming/99.Manuscript/Data/intermediate/'

# %%
output_path = int_out_dir + 'goea_DF_collection_public_100iter'

with open(output_path, 'wb') as output_file:
 
    pickle.dump(goea_DF_collection_public, output_file)

# %%
output_path = int_out_dir + 'goea_DF_collection_experiment_100iter'

with open(output_path, 'wb') as output_file:
 
    pickle.dump(goea_DF_collection_experiment, output_file)

# %%
input_path = int_out_dir + 'goea_DF_collection_public_100iter'
with open(input_path, 'rb') as input_file:
 
    goea_DF_collection_public = pickle.load(input_file)

# %%
input_path = int_out_dir + 'goea_DF_collection_experiment_100iter'
with open(input_path, 'rb') as input_file:
 
    goea_DF_collection_experiment = pickle.load(input_file)

# %%
assert len(goea_DF_collection_public)==100

# %%
assert len(goea_DF_collection_experiment)==100

# %% [markdown]
# #### Plot GO terms of interest

# %%
GOterm_list = ['cell cycle', 'defense response to virus']

# %%
GOterm_list = ['defense response to virus', 'immune system process', 'cellular response to interferon-beta']

# %%
GOterm_list = ['oxidation-reduction process', 
              'tricarboxylic acid cycle', 'oxidative phosphorylation', 'glycolytic process', 
              'ATP synthesis coupled proton transport', 'electron transport chain']

# %%
GOterm_list = ['lipid metabolic process', 'cellular lipid catabolic process', 'cell adhesion']

# %%
GOterm_list = ['cell cycle', 'ribosome biogenesis', 'translation', 
               'mitochondrial translation', 'mRNA processing', 
              'rRNA processing']

# %%
# Figure 3E, mid and bottom
for GOterm_oi in GOterm_list: 
    iteration, goea_DF_list_experiment = goea_DF_collection_experiment[0]
    data_experimental_up = {}
    for cluster, _, _, _ in goea_DF_list_experiment:
        data_experimental_up[cluster] = []

    for iteration, goea_DF_list_experiment in goea_DF_collection_experiment:
        for cluster, goea_summary_MF, goea_summary_BP, goea_summary_CC in goea_DF_list_experiment:
            data_experimental_up[cluster].append(goea_summary_BP.iloc[np.where(goea_summary_BP['goName']==GOterm_oi)[0][0],:]['goAdjP'])

    df_experimental_up = pd.DataFrame(data_experimental_up)

    df_experimental_up = df_experimental_up.T

    df_experimental_up = -np.log10(df_experimental_up)

    df_experimental_up['mean'] = df_experimental_up.mean(axis=1)

    df_experimental_up['std'] = df_experimental_up.std(axis=1)


    iteration, goea_DF_list_public = goea_DF_collection_public[0]
    data_public_up = {}
    for cluster, _, _, _ in goea_DF_list_public:
        data_public_up[cluster] = []

    for iteration, goea_DF_list_public in goea_DF_collection_public:
        for cluster, goea_summary_MF, goea_summary_BP, goea_summary_CC in goea_DF_list_public:
            data_public_up[cluster].append(goea_summary_BP.iloc[np.where(goea_summary_BP['goName']==GOterm_oi)[0][0],:]['goAdjP'])

    df_public_up = pd.DataFrame(data_public_up)

    df_public_up = df_public_up.T

    df_public_up = -np.log10(df_public_up)

    df_public_up['mean'] = df_public_up.mean(axis=1)

    df_public_up['std'] = df_public_up.std(axis=1)


#    row_order = ['Resident_astrocytes', '1-Reprogrammed_astrocytes/qNSC-like', '8-Early-aNSCs', 
#                '3-Mid-aNSCs', '5-Late-aNSCs/NPC-like', '6-NPC/early-neurobalsts', 
#                '0-Mid-neuroblasts', '7-Late-neuroblats/maturing_neurons']
    
    row_order = ['Resident astrocytes', 'Lenti-astrocytes', 'Early NPCs', 
            'Mid NPCs', 'Late NPCs', 'Early neuroblasts', 
            'Mid neuroblasts', 'Late neuroblasts']

    fig, ax = plt.subplots(figsize=(8,4))
    x = np.arange(len(row_order))

    y_experimental_up = df_experimental_up.loc[row_order]['mean']
    error_experimental_up = df_experimental_up.loc[row_order]['std']

    y_public_up = df_public_up.loc[row_order]['mean']
    error_public_up = df_public_up.loc[row_order]['std']

    plt.errorbar(x, y_experimental_up, error_experimental_up/2, capsize=5)
    plt.errorbar(x, y_public_up, error_public_up/2, capsize=5)

    plt.xticks(x, row_order, rotation=90)
    plt.legend(['Experimental up', 'Public up'], loc='best')

    plt.title('Enrichment of GO term: '+GOterm_oi)

#    plt.savefig('/project/GCRB/Hon_lab/s418610/Projects/03.Invivo_neuronal_reprogramming/99.Manuscript/Figures_v2/Figure1/linechart_'+GOterm_oi+'_DEGs.pdf')
    plt.show()
