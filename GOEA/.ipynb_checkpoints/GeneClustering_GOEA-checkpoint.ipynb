# %% [markdown]
# # Run a Gene Ontology Enrichment Analysis (GOEA)
# * Use gene clusters (chi-square p value filter; louvain clustering) resulted from .ipynb #9.
# * Calculate enriched GO terms and plot barplots

# %%
import sys
import pickle
print(sys.executable)
print(sys.path)
print(sys.version)
# Out:
# /home2/s418610/.conda/envs/py37_res_diffxpy/bin/python
# ['/home2/s418610/jupyter_notebooks/03.Invivo_neuronal_reprogramming/Manuscript/to_GitHub/GOEA', '', '/cm/shared/apps/cnvkit/0.9.5/lib/python3.6/site-packages', '/cm/shared/apps/python/3.6.4-anaconda/lib', '/cm/shared/apps/jupyterkernel-matlab/0.16.1/lib/python3.6/site-packages', '/cm/shared/apps/python/2.7.x-anaconda/lib', '/home2/s418610/.conda/envs/py37_res_diffxpy/lib/python37.zip', '/home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7', '/home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/lib-dynload', '/home2/s418610/.local/lib/python3.7/site-packages', '/home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages', '/home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages/fa2-0.3.5-py3.7-linux-x86_64.egg', '/home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages/batchglm', '/home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages/diffxpy', '/home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages/IPython/extensions', '/home2/s418610/.ipython']
# 3.7.3 (default, Mar 27 2019, 22:11:17)
# [GCC 7.3.0]

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import statsmodels.api as sm
import scanpy as sc
import anndata

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# import scanpy as sc
# import harmonypy as hm

# %%
plt.rcParams['figure.figsize']=(8,8) #rescale figures
# sc.settings.verbosity = 3

print('numpy', np.__version__)
print('pandas', pd.__version__)
# print('scipy', scipy.__version__)
# print('sklearn', sklearn.__version__)
print('statsmodels', sm.__version__)
print('matplotlib', mpl.__version__)
print('seaborn', sns.__version__)

sc.logging.print_versions()

# !date +%F
# Out:
# numpy 1.20.3
# pandas 0.25.2
# statsmodels 0.10.1
# matplotlib 3.1.3
# seaborn 0.9.0
# /home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:284: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_Gram=True, verbose=0,
# /home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1101: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1127: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# /home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1362: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1602: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1738: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# /home2/s418610/.conda/envs/py37_res_diffxpy/lib/python3.7/site-packages/sklearn/decomposition/online_lda.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps
# scanpy==1.4.5.post1 anndata==0.6.22.post1 umap==0.3.10 numpy==1.20.3 scipy==1.4.1 pandas==0.25.2 scikit-learn==0.21.3 statsmodels==0.10.1 python-igraph==0.7.1 louvain==0.6.1
# 2021-08-23

# %% [markdown]
# ## 1. Download Ontologies and Associations

# %% [markdown]
# ### 1a. Download Ontologies, if necessary

# %%
# Get http://geneontology.org/ontology/go-basic.obo
from goatools.base import download_go_basic_obo
obo_fname = download_go_basic_obo()
# Out:
#   EXISTS: go-basic.obo

# %% [markdown]
# ### 1b. Download Associations, if necessary

# %%
# Get ftp://ftp.ncbi.nlm.nih.gov/gene/DATA/gene2go.gz
from goatools.base import download_ncbi_associations
fin_gene2go = download_ncbi_associations()
# Out:
#   EXISTS: gene2go

# %% [markdown]
# ## 2. Load Ontologies, Associations and Background gene set

# %% [markdown]
# ### 2a. Load Ontologies

# %%
from goatools.obo_parser import GODag

obodag = GODag("go-basic.obo")
# Out:
# go-basic.obo: fmt(1.2) rel(2020-09-10) 47,314 GO Terms

# %% [markdown]
# ### 2b. Load Associations

# %%
from __future__ import print_function
from goatools.anno.genetogo_reader import Gene2GoReader

# %%
# Read NCBI's gene2go. Store annotations in a list of namedtuples
objanno = Gene2GoReader(fin_gene2go, taxids=[10090]) # Taxid 10090 is Mus musculus

# Get namespace2association where:
#    namespace is:
#        BP: biological_process               
#        MF: molecular_function
#        CC: cellular_component
#    assocation is a dict:
#        key: NCBI GeneID
#        value: A set of GO IDs associated with that gene
ns2assoc = objanno.get_ns2assc()

for nspc, id2gos in ns2assoc.items():
    print("{NS} {N:,} annotated mouse genes".format(NS=nspc, N=len(id2gos)))
# Out:
# HMS:0:00:05.253747 383,293 annotations READ: gene2go
# 1 taxids stored: 10090
# MF 17,115 annotated mouse genes
# BP 18,414 annotated mouse genes
# CC 19,207 annotated mouse genes

# %% [markdown]
# ### 2c. Load Background gene set
# In this example, the background is all mouse protein-codinge genes

# %%
from goatools.test_data.genes_NCBI_10090_ProteinCoding import GENEID2NT as GeneID2nt_mus
# from goatools.test_data.genes_NCBI_10090_All import GENEID2NT as GeneID2nt_mus

# %%
len(GeneID2nt_mus.keys())
# Out:
# 28212

# %% [markdown]
# ## 3. Initialize a GOEA object
# The GOEA object holds the Ontologies, Associations, and background.

# %%
from goatools.goea.go_enrichment_ns import GOEnrichmentStudyNS

goeaobj = GOEnrichmentStudyNS(
        GeneID2nt_mus.keys(), # List of mouse protein-coding genes
        ns2assoc, # geneid/GO associations
        obodag, # Ontologies
        propagate_counts = False,
        alpha = 0.05, # default significance cut-off
        methods = ['fdr_bh']) # defult multipletest correction method
# Out:
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  62% 17,364 of 28,212 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  66% 18,550 of 28,212 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  59% 16,739 of 28,212 population items found in association

# %% [markdown]
# ## 4. Read study genes
# * Gene symbols from DE analysis need to be converted to gene IDs first

# %% [markdown]
# #### Making a reference dictionary to convert symbols of my genes to gene IDs

# %%
GeneID2Symbol_dict = {}

# %%
for GeneID in list(GeneID2nt_mus.keys()):
    Symbols = []
    Symbols.append(GeneID2nt_mus[GeneID].Symbol)
    if not GeneID2nt_mus[GeneID].Aliases == '':
        for alias in GeneID2nt_mus[GeneID].Aliases.split(','):
            Symbols.append(alias.strip())
    GeneID2Symbol_dict[GeneID] = Symbols

# %% [markdown]
# ##### Example search of a gene symbol

# %%
gene_search = 'Ascl1'

# %%
for GeneID, names in GeneID2Symbol_dict.items():
    if gene_search in names:
        print(GeneID)
# Out:
# 17172

# %% [markdown]
# #### Loading my genes and convert symbols to IDs

# %%
geneclustering_dir = '/project/GCRB/Hon_lab/s418610/Projects/03.Invivo_neuronal_reprogramming/analysis/Cluster_with_10X_20k/data/10x_remapped/Revision/GeneClustering/'

# %%
input_path = geneclustering_dir + 'adata_genes'
with open(input_path, 'rb') as input_file:
 
    adata_genes = pickle.load(input_file)

# %%
adata_genes
# Out:
# AnnData object with n_obs × n_vars = 2584 × 4607
#     obs: 'gene_ids', 'feature_types', 'genome', 'n_cells', 'p_val_adj', 'n_counts', 'n_cells_experimental', 'louvain', 'log10_n_cells_experimental'
#     var: 'library_name', 'batch', 'lenti_count', 'lenti_log1p_count', 'tdT_count', 'tdT_log1p_count', 'doublet_scores', 'predicted_doublets', 'n_counts', 'log_counts', 'n_genes', 'mt_count', 'mt_frac', 'n_counts_all', 'louvain', 'dpt_pseudotime', 'rank_pseudotime'
#     uns: 'pca', 'neighbors', 'louvain', 'paga', 'louvain_sizes', 'louvain_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'

# %% [markdown]
# ## 5. Run Gene Ontology Enrichment Analysis (GOEA)
# You may choose to keep all results or just the significant results. Here, we choose to keep only the significant results.

# %%
adata_genes.obs['louvain'].value_counts()
# Out:
# 0     565
# 1     421
# 2     299
# 3     287
# 4     265
# 5     237
# 6     164
# 7     106
# 8      79
# 9      63
# 10     54
# 11     44
# Name: louvain, dtype: int64

# %% [markdown]
# #### Loop over all clusters

# %%
goea_gene_clusters = []
for cluster in adata_genes.obs['louvain'].value_counts().index:
    genes_in_cluster = adata_genes.obs.index[np.where(adata_genes.obs['louvain']==cluster)]
    geneids_study = []
    for gene_search in genes_in_cluster:
        for GeneID, names in GeneID2Symbol_dict.items():
            if gene_search in names:
    #            print(GeneID)
                geneids_study.append(GeneID)
                break

    goea_results_all = goeaobj.run_study(geneids_study)
    goea_results_sig = [r for r in goea_results_all if r.p_fdr_bh < 0.05]
    goea_gene_clusters.append((cluster, genes_in_cluster, geneids_study, goea_results_sig))
# Out:
# Run BP Gene Ontology Analysis: current study set of 550 IDs ...
#  93%    509 of    550 study items found in association
# 100%    550 of    550 study items found in population(28212)
# Calculating 12,357 uncorrected p-values using fisher_scipy_stats
#   12,357 GO terms are associated with 17,364 of 28,212 population items
#    3,049 GO terms are associated with    509 of    550 study items
#   METHOD fdr_bh:
#       81 GO terms found significant (< 0.05=alpha) ( 80 enriched +   1 purified): statsmodels fdr_bh
#      323 study items associated with significant GO IDs (enriched)
#        1 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 550 IDs ...
#  97%    531 of    550 study items found in association
# 100%    550 of    550 study items found in population(28212)
# Calculating 1,745 uncorrected p-values using fisher_scipy_stats
#    1,745 GO terms are associated with 18,550 of 28,212 population items
#      458 GO terms are associated with    531 of    550 study items
#   METHOD fdr_bh:
#       76 GO terms found significant (< 0.05=alpha) ( 76 enriched +   0 purified): statsmodels fdr_bh
#      506 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 550 IDs ...
#  89%    488 of    550 study items found in association
# 100%    550 of    550 study items found in population(28212)
# Calculating 4,197 uncorrected p-values using fisher_scipy_stats
#    4,197 GO terms are associated with 16,739 of 28,212 population items
#      844 GO terms are associated with    488 of    550 study items
#   METHOD fdr_bh:
#       19 GO terms found significant (< 0.05=alpha) ( 18 enriched +   1 purified): statsmodels fdr_bh
#      344 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 413 IDs ...
#  94%    388 of    412 study items found in association
# 100%    412 of    413 study items found in population(28212)
# Calculating 12,357 uncorrected p-values using fisher_scipy_stats
#   12,357 GO terms are associated with 17,364 of 28,212 population items
#    1,825 GO terms are associated with    388 of    412 study items
#   METHOD fdr_bh:
#       89 GO terms found significant (< 0.05=alpha) ( 87 enriched +   2 purified): statsmodels fdr_bh
#      312 study items associated with significant GO IDs (enriched)
#        1 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 413 IDs ...
#  97%    400 of    412 study items found in association
# 100%    412 of    413 study items found in population(28212)
# Calculating 1,745 uncorrected p-values using fisher_scipy_stats
#    1,745 GO terms are associated with 18,550 of 28,212 population items
#      430 GO terms are associated with    400 of    412 study items
#   METHOD fdr_bh:
#      108 GO terms found significant (< 0.05=alpha) (102 enriched +   6 purified): statsmodels fdr_bh
#      378 study items associated with significant GO IDs (enriched)
#       66 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 413 IDs ...
#  88%    363 of    412 study items found in association
# 100%    412 of    413 study items found in population(28212)
# Calculating 4,197 uncorrected p-values using fisher_scipy_stats
#    4,197 GO terms are associated with 16,739 of 28,212 population items
#      526 GO terms are associated with    363 of    412 study items
#   METHOD fdr_bh:
#       54 GO terms found significant (< 0.05=alpha) ( 52 enriched +   2 purified): statsmodels fdr_bh
#      312 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 285 IDs ...
#  89%    254 of    285 study items found in association
# 100%    285 of    285 study items found in population(28212)
# Calculating 12,357 uncorrected p-values using fisher_scipy_stats
#   12,357 GO terms are associated with 17,364 of 28,212 population items
#    1,663 GO terms are associated with    254 of    285 study items
#   METHOD fdr_bh:
#        9 GO terms found significant (< 0.05=alpha) (  8 enriched +   1 purified): statsmodels fdr_bh
#       47 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 285 IDs ...
#  94%    269 of    285 study items found in association
# 100%    285 of    285 study items found in population(28212)
# Calculating 1,745 uncorrected p-values using fisher_scipy_stats
#    1,745 GO terms are associated with 18,550 of 28,212 population items
#      313 GO terms are associated with    269 of    285 study items
#   METHOD fdr_bh:
#       23 GO terms found significant (< 0.05=alpha) ( 23 enriched +   0 purified): statsmodels fdr_bh
#      260 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 285 IDs ...
#  82%    234 of    285 study items found in association
# 100%    285 of    285 study items found in population(28212)
# Calculating 4,197 uncorrected p-values using fisher_scipy_stats
#    4,197 GO terms are associated with 16,739 of 28,212 population items
#      509 GO terms are associated with    234 of    285 study items
#   METHOD fdr_bh:
#       15 GO terms found significant (< 0.05=alpha) ( 14 enriched +   1 purified): statsmodels fdr_bh
#      146 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 280 IDs ...
#  88%    247 of    280 study items found in association
# 100%    280 of    280 study items found in population(28212)
# Calculating 12,357 uncorrected p-values using fisher_scipy_stats
#   12,357 GO terms are associated with 17,364 of 28,212 population items
#    1,215 GO terms are associated with    247 of    280 study items
#   METHOD fdr_bh:
#       21 GO terms found significant (< 0.05=alpha) ( 19 enriched +   2 purified): statsmodels fdr_bh
#      117 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 280 IDs ...
#  95%    266 of    280 study items found in association
# 100%    280 of    280 study items found in population(28212)
# Calculating 1,745 uncorrected p-values using fisher_scipy_stats
#    1,745 GO terms are associated with 18,550 of 28,212 population items
#      361 GO terms are associated with    266 of    280 study items
#   METHOD fdr_bh:
#       29 GO terms found significant (< 0.05=alpha) ( 29 enriched +   0 purified): statsmodels fdr_bh
#      238 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 280 IDs ...
#  82%    229 of    280 study items found in association
# 100%    280 of    280 study items found in population(28212)
# Calculating 4,197 uncorrected p-values using fisher_scipy_stats
#    4,197 GO terms are associated with 16,739 of 28,212 population items
#      387 GO terms are associated with    229 of    280 study items
#   METHOD fdr_bh:
#        8 GO terms found significant (< 0.05=alpha) (  7 enriched +   1 purified): statsmodels fdr_bh
#      140 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 256 IDs ...
#  95%    242 of    256 study items found in association
# 100%    256 of    256 study items found in population(28212)
# Calculating 12,357 uncorrected p-values using fisher_scipy_stats
#   12,357 GO terms are associated with 17,364 of 28,212 population items
#    1,154 GO terms are associated with    242 of    256 study items
#   METHOD fdr_bh:
#       34 GO terms found significant (< 0.05=alpha) ( 32 enriched +   2 purified): statsmodels fdr_bh
#      124 study items associated with significant GO IDs (enriched)
#        2 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 256 IDs ...
#  97%    248 of    256 study items found in association
# 100%    256 of    256 study items found in population(28212)
# Calculating 1,745 uncorrected p-values using fisher_scipy_stats
#    1,745 GO terms are associated with 18,550 of 28,212 population items
#      355 GO terms are associated with    248 of    256 study items
#   METHOD fdr_bh:
#       69 GO terms found significant (< 0.05=alpha) ( 68 enriched +   1 purified): statsmodels fdr_bh
#      234 study items associated with significant GO IDs (enriched)
#       23 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 256 IDs ...
#  87%    223 of    256 study items found in association
# 100%    256 of    256 study items found in population(28212)
# Calculating 4,197 uncorrected p-values using fisher_scipy_stats
#    4,197 GO terms are associated with 16,739 of 28,212 population items
#      424 GO terms are associated with    223 of    256 study items
#   METHOD fdr_bh:
#       23 GO terms found significant (< 0.05=alpha) ( 22 enriched +   1 purified): statsmodels fdr_bh
#      179 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 223 IDs ...
#  91%    203 of    222 study items found in association
# 100%    222 of    223 study items found in population(28212)
# Calculating 12,357 uncorrected p-values using fisher_scipy_stats
#   12,357 GO terms are associated with 17,364 of 28,212 population items
#    1,516 GO terms are associated with    203 of    222 study items
#   METHOD fdr_bh:
#       41 GO terms found significant (< 0.05=alpha) ( 41 enriched +   0 purified): statsmodels fdr_bh
#      119 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 223 IDs ...
#  95%    211 of    222 study items found in association
# 100%    222 of    223 study items found in population(28212)
# Calculating 1,745 uncorrected p-values using fisher_scipy_stats
#    1,745 GO terms are associated with 18,550 of 28,212 population items
#      322 GO terms are associated with    211 of    222 study items
#   METHOD fdr_bh:
#       57 GO terms found significant (< 0.05=alpha) ( 57 enriched +   0 purified): statsmodels fdr_bh
#      207 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 223 IDs ...
#  89%    197 of    222 study items found in association
# 100%    222 of    223 study items found in population(28212)
# Calculating 4,197 uncorrected p-values using fisher_scipy_stats
#    4,197 GO terms are associated with 16,739 of 28,212 population items
#      403 GO terms are associated with    197 of    222 study items
#   METHOD fdr_bh:
#       33 GO terms found significant (< 0.05=alpha) ( 32 enriched +   1 purified): statsmodels fdr_bh
#      169 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 160 IDs ...
#  94%    150 of    160 study items found in association
# 100%    160 of    160 study items found in population(28212)
# Calculating 12,357 uncorrected p-values using fisher_scipy_stats
#   12,357 GO terms are associated with 17,364 of 28,212 population items
#    1,256 GO terms are associated with    150 of    160 study items
#   METHOD fdr_bh:
#       27 GO terms found significant (< 0.05=alpha) ( 27 enriched +   0 purified): statsmodels fdr_bh
#       72 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 160 IDs ...
#  98%    157 of    160 study items found in association
# 100%    160 of    160 study items found in population(28212)
# Calculating 1,745 uncorrected p-values using fisher_scipy_stats
#    1,745 GO terms are associated with 18,550 of 28,212 population items
#      236 GO terms are associated with    157 of    160 study items
#   METHOD fdr_bh:
#       37 GO terms found significant (< 0.05=alpha) ( 37 enriched +   0 purified): statsmodels fdr_bh
#      148 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 160 IDs ...
#  92%    148 of    160 study items found in association
# 100%    160 of    160 study items found in population(28212)
# Calculating 4,197 uncorrected p-values using fisher_scipy_stats
#    4,197 GO terms are associated with 16,739 of 28,212 population items
#      385 GO terms are associated with    148 of    160 study items
#   METHOD fdr_bh:
#       22 GO terms found significant (< 0.05=alpha) ( 22 enriched +   0 purified): statsmodels fdr_bh
#      112 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 102 IDs ...
#  96%     98 of    102 study items found in association
# 100%    102 of    102 study items found in population(28212)
# Calculating 12,357 uncorrected p-values using fisher_scipy_stats
#   12,357 GO terms are associated with 17,364 of 28,212 population items
#      419 GO terms are associated with     98 of    102 study items
#   METHOD fdr_bh:
#       62 GO terms found significant (< 0.05=alpha) ( 62 enriched +   0 purified): statsmodels fdr_bh
#       88 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 102 IDs ...
#  99%    101 of    102 study items found in association
# 100%    102 of    102 study items found in population(28212)
# Calculating 1,745 uncorrected p-values using fisher_scipy_stats
#    1,745 GO terms are associated with 18,550 of 28,212 population items
#      125 GO terms are associated with    101 of    102 study items
#   METHOD fdr_bh:
#       54 GO terms found significant (< 0.05=alpha) ( 52 enriched +   2 purified): statsmodels fdr_bh
#      100 study items associated with significant GO IDs (enriched)
#        7 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 102 IDs ...
#  84%     86 of    102 study items found in association
# 100%    102 of    102 study items found in population(28212)
# Calculating 4,197 uncorrected p-values using fisher_scipy_stats
#    4,197 GO terms are associated with 16,739 of 28,212 population items
#      135 GO terms are associated with     86 of    102 study items
#   METHOD fdr_bh:
#       19 GO terms found significant (< 0.05=alpha) ( 19 enriched +   0 purified): statsmodels fdr_bh
#       76 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 78 IDs ...
#  99%     77 of     78 study items found in association
# 100%     78 of     78 study items found in population(28212)
# Calculating 12,357 uncorrected p-values using fisher_scipy_stats
#   12,357 GO terms are associated with 17,364 of 28,212 population items
#      253 GO terms are associated with     77 of     78 study items
#   METHOD fdr_bh:
#       13 GO terms found significant (< 0.05=alpha) ( 13 enriched +   0 purified): statsmodels fdr_bh
#       69 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 78 IDs ...
# 100%     78 of     78 study items found in association
# 100%     78 of     78 study items found in population(28212)
# Calculating 1,745 uncorrected p-values using fisher_scipy_stats
#    1,745 GO terms are associated with 18,550 of 28,212 population items
#       92 GO terms are associated with     78 of     78 study items
#   METHOD fdr_bh:
#       20 GO terms found significant (< 0.05=alpha) ( 19 enriched +   1 purified): statsmodels fdr_bh
#       78 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 78 IDs ...
#  97%     76 of     78 study items found in association
# 100%     78 of     78 study items found in population(28212)
# Calculating 4,197 uncorrected p-values using fisher_scipy_stats
#    4,197 GO terms are associated with 16,739 of 28,212 population items
#      113 GO terms are associated with     76 of     78 study items
#   METHOD fdr_bh:
#       13 GO terms found significant (< 0.05=alpha) ( 13 enriched +   0 purified): statsmodels fdr_bh
#       69 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 62 IDs ...
#  98%     61 of     62 study items found in association
# 100%     62 of     62 study items found in population(28212)
# Calculating 12,357 uncorrected p-values using fisher_scipy_stats
#   12,357 GO terms are associated with 17,364 of 28,212 population items
#      319 GO terms are associated with     61 of     62 study items
#   METHOD fdr_bh:
#       45 GO terms found significant (< 0.05=alpha) ( 45 enriched +   0 purified): statsmodels fdr_bh
#       53 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 62 IDs ...
#  98%     61 of     62 study items found in association
# 100%     62 of     62 study items found in population(28212)
# Calculating 1,745 uncorrected p-values using fisher_scipy_stats
#    1,745 GO terms are associated with 18,550 of 28,212 population items
#       88 GO terms are associated with     61 of     62 study items
#   METHOD fdr_bh:
#       26 GO terms found significant (< 0.05=alpha) ( 24 enriched +   2 purified): statsmodels fdr_bh
#       58 study items associated with significant GO IDs (enriched)
#        2 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 62 IDs ...
#  94%     58 of     62 study items found in association
# 100%     62 of     62 study items found in population(28212)
# Calculating 4,197 uncorrected p-values using fisher_scipy_stats
#    4,197 GO terms are associated with 16,739 of 28,212 population items
#      143 GO terms are associated with     58 of     62 study items
#   METHOD fdr_bh:
#       20 GO terms found significant (< 0.05=alpha) ( 20 enriched +   0 purified): statsmodels fdr_bh
#       51 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 54 IDs ...
#  98%     53 of     54 study items found in association
# 100%     54 of     54 study items found in population(28212)
# Calculating 12,357 uncorrected p-values using fisher_scipy_stats
#   12,357 GO terms are associated with 17,364 of 28,212 population items
#      347 GO terms are associated with     53 of     54 study items
#   METHOD fdr_bh:
#       44 GO terms found significant (< 0.05=alpha) ( 44 enriched +   0 purified): statsmodels fdr_bh
#       48 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 54 IDs ...
# 100%     54 of     54 study items found in association
# 100%     54 of     54 study items found in population(28212)
# Calculating 1,745 uncorrected p-values using fisher_scipy_stats
#    1,745 GO terms are associated with 18,550 of 28,212 population items
#       73 GO terms are associated with     54 of     54 study items
#   METHOD fdr_bh:
#       22 GO terms found significant (< 0.05=alpha) ( 22 enriched +   0 purified): statsmodels fdr_bh
#       53 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 54 IDs ...
#  94%     51 of     54 study items found in association
# 100%     54 of     54 study items found in population(28212)
# Calculating 4,197 uncorrected p-values using fisher_scipy_stats
#    4,197 GO terms are associated with 16,739 of 28,212 population items
#      119 GO terms are associated with     51 of     54 study items
#   METHOD fdr_bh:
#       14 GO terms found significant (< 0.05=alpha) ( 14 enriched +   0 purified): statsmodels fdr_bh
#       31 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run BP Gene Ontology Analysis: current study set of 44 IDs ...
#  91%     40 of     44 study items found in association
# 100%     44 of     44 study items found in population(28212)
# Calculating 12,357 uncorrected p-values using fisher_scipy_stats
#   12,357 GO terms are associated with 17,364 of 28,212 population items
#      468 GO terms are associated with     40 of     44 study items
#   METHOD fdr_bh:
#       11 GO terms found significant (< 0.05=alpha) ( 11 enriched +   0 purified): statsmodels fdr_bh
#       23 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 44 IDs ...
#  91%     40 of     44 study items found in association
# 100%     44 of     44 study items found in population(28212)
# Calculating 1,745 uncorrected p-values using fisher_scipy_stats
#    1,745 GO terms are associated with 18,550 of 28,212 population items
#      162 GO terms are associated with     40 of     44 study items
#   METHOD fdr_bh:
#       42 GO terms found significant (< 0.05=alpha) ( 42 enriched +   0 purified): statsmodels fdr_bh
#       39 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 44 IDs ...
#  95%     42 of     44 study items found in association
# 100%     44 of     44 study items found in population(28212)
# Calculating 4,197 uncorrected p-values using fisher_scipy_stats
#    4,197 GO terms are associated with 16,739 of 28,212 population items
#      178 GO terms are associated with     42 of     44 study items
#   METHOD fdr_bh:
#        9 GO terms found significant (< 0.05=alpha) (  9 enriched +   0 purified): statsmodels fdr_bh
#       30 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)

# %%
# Double check that there are 12 results, corresponding to 12 gene clusters
len(goea_gene_clusters)
# Out:
# 12

# %% [markdown]
# #### Extracting results

# %%
goea_DF_gene_clusters = []
for cluster, _, _, goea_results_sig in goea_gene_clusters:

    goID = []
    goName = []
    goNamespace = []
    goEnrichment = []
    goAdjP = []
    study_count = []
    study_n = []
    pop_count = []
    pop_n = []
    for goea_result in goea_results_sig:
        goID.append(goea_result.goterm.id)
        goName.append(goea_result.goterm.name)
        goNamespace.append(goea_result.goterm.namespace)
        goEnrichment.append(goea_result.enrichment)
        goAdjP.append(goea_result.p_fdr_bh)
        study_count.append(goea_result.study_count)
        study_n.append(goea_result.study_n)
        pop_count.append(goea_result.pop_count)
        pop_n.append(goea_result.pop_n)

    goea_summary = pd.DataFrame(data={'goID': goID,
                                     'goName': goName, 
                                     'goNamespace': goNamespace, 
                                     'goEnrichment': goEnrichment, 
                                     'goAdjP': goAdjP, 
                                     'study_count': study_count, 
                                     'study_n': study_n, 
                                     'pop_count': pop_count, 
                                     'pop_n': pop_n})

    # goea_summary.sort_values(by='goAdjP', ascending=True, inplace=True)

    # goea_summary = goea_summary[goea_summary['goEnrichment']=='e']

    goea_summary_MF = goea_summary[goea_summary['goNamespace']=='molecular_function']
    goea_summary_BP = goea_summary[goea_summary['goNamespace']=='biological_process']
    goea_summary_CC = goea_summary[goea_summary['goNamespace']=='cellular_component']

    goea_DF_gene_clusters.append((cluster, goea_summary_MF, goea_summary_BP, goea_summary_CC))

# %%
GOEA_dir = '/project/GCRB/Hon_lab/s418610/Projects/03.Invivo_neuronal_reprogramming/analysis/Cluster_with_10X_20k/data/10x_remapped/Revision/GOEA/'

# %%
# for cluster, goea_summary_MF, goea_summary_BP, goea_summary_CC in goea_DF_gene_clusters:
#     goea_summary_MF.to_csv(GOEA_dir + 'gene_cluster_'+cluster+'_GOEA_summary_MF.csv', index=False)
#     goea_summary_BP.to_csv(GOEA_dir + 'gene_cluster_'+cluster+'_GOEA_summary_BP.csv', index=False)
#     goea_summary_CC.to_csv(GOEA_dir + 'gene_cluster_'+cluster+'_GOEA_summary_CC.csv', index=False)

# %% [markdown]
# ##### Write and read data

# %%
output_path = GOEA_dir + 'goea_DF_gene_clusters'

with open(output_path, 'wb') as output_file:
 
    pickle.dump(goea_DF_gene_clusters, output_file)

# %%
input_path = GOEA_dir + 'goea_DF_gene_clusters'
with open(input_path, 'rb') as input_file:
 
    goea_DF_gene_clusters = pickle.load(input_file)

# %%
assert len(goea_DF_gene_clusters)==12

# %% [markdown]
# ## 6. Plot top enriched GO terms
# One plot for each namespace.

# %% [markdown]
# #### Understanding the output

# %% [markdown]
# ### Loop over all clusters

# %%
# Figure 4E
for cluster, _, _, goea_results_sig in goea_gene_clusters:
    print('Current gene cluster under examination: Louvain', cluster)

    print(len(goea_results_sig), 'GO terms are enriched in Louvain cluster', cluster)

    goID = []
    goName = []
    goNamespace = []
    goEnrichment = []
    goAdjP = []
    study_count = []
    study_n = []
    pop_count = []
    pop_n = []
    for goea_result in goea_results_sig:
        goID.append(goea_result.goterm.id)
        goName.append(goea_result.goterm.name)
        goNamespace.append(goea_result.goterm.namespace)
        goEnrichment.append(goea_result.enrichment)
        goAdjP.append(goea_result.p_fdr_bh)
        study_count.append(goea_result.study_count)
        study_n.append(goea_result.study_n)
        pop_count.append(goea_result.pop_count)
        pop_n.append(goea_result.pop_n)

    goea_summary = pd.DataFrame(data={'goID': goID,
                                     'goName': goName, 
                                     'goNamespace': goNamespace, 
                                     'goEnrichment': goEnrichment, 
                                     'goAdjP': goAdjP, 
                                     'study_count': study_count, 
                                     'study_n': study_n, 
                                     'pop_count': pop_count, 
                                     'pop_n': pop_n})

    goea_summary.sort_values(by='goAdjP', ascending=True, inplace=True)

    goea_summary = goea_summary[goea_summary['goEnrichment']=='e']

    goea_summary_MF = goea_summary[goea_summary['goNamespace']=='molecular_function']
    goea_summary_BP = goea_summary[goea_summary['goNamespace']=='biological_process']
    goea_summary_CC = goea_summary[goea_summary['goNamespace']=='cellular_component']

    print(goea_summary_MF.shape[0], 'MF terms are significantly enriched. ')
    print(goea_summary_BP.shape[0], 'BP terms are significantly enriched. ')
    print(goea_summary_CC.shape[0], 'CC terms are significantly enriched. ')

    #### Barplot

    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(3, 5), sharex=True)
    # plt.subplots_adjust(hspace=0.5)

    # BP
    y_pos = np.arange(min(10, goea_summary_BP.shape[0]))
    y_lab = goea_summary_BP['goName'][:10]
    data = -np.log10(goea_summary_BP['goAdjP'][:10])
    colors = np.where(data > 20, 'tab:red', np.where(data > 10, 'tab:orange', 'tab:blue') )
    
    for lab in y_lab:
        print(lab)
    
    ax.barh(y_pos, data, align='center', color=colors)
    ax.set_yticks(y_pos)
    ax.set_yticklabels(y_lab)
    ax.invert_yaxis()  # labels read top-to-bottom
    # axes[0].set_xlabel('- log10 adj. p-value')
#     ax.set_title('Enriched GO biological process terms')

    if len(data.tolist()) > 0:
        maxtick = int(max(data.tolist())+5)
    else:
        maxtick = 5
    ax.set_xticks(np.arange(0, maxtick, 5))
    ax.set_xticklabels(np.arange(0, maxtick, 5))
    
#    plt.show()
#     plt.savefig('/project/GCRB/Hon_lab/s418610/Projects/03.Invivo_neuronal_reprogramming/99.Manuscript/Figures_v2/Figure2/GO/cluster'+cluster+'_BP_barchart.pdf')
# Out:
# Current gene cluster under examination: Louvain 0
# 176 GO terms are enriched in Louvain cluster 0
# 18 MF terms are significantly enriched.
# 80 BP terms are significantly enriched.
# 76 CC terms are significantly enriched.
# lipid metabolic process
# cell adhesion
# multicellular organism development
# cell migration
# cell differentiation
# glycogen metabolic process
# cell-cell adhesion
# circadian regulation of gene expression
# apoptotic cell clearance
# intracellular signal transduction
# Current gene cluster under examination: Louvain 1
# 251 GO terms are enriched in Louvain cluster 1
# 52 MF terms are significantly enriched.
# 87 BP terms are significantly enriched.
# 102 CC terms are significantly enriched.
# cell cycle
# cell division
# mRNA processing
# RNA splicing
# DNA repair
# cellular response to DNA damage stimulus
# mRNA splicing, via spliceosome
# chromosome segregation
# DNA replication
# mitotic cell cycle
# Current gene cluster under examination: Louvain 2
# 47 GO terms are enriched in Louvain cluster 2
# 14 MF terms are significantly enriched.
# 8 BP terms are significantly enriched.
# 23 CC terms are significantly enriched.
# oxidation-reduction process
# fatty acid beta-oxidation
# fatty acid beta-oxidation using acyl-CoA dehydrogenase
# liver development
# fatty acid metabolic process
# tricarboxylic acid cycle
# regulation of blood pressure
# succinate metabolic process
# Current gene cluster under examination: Louvain 3
# 58 GO terms are enriched in Louvain cluster 3
# 7 MF terms are significantly enriched.
# 19 BP terms are significantly enriched.
# 29 CC terms are significantly enriched.
# translation
# mitochondrial translation
# protein transport
# mitochondrial electron transport, NADH to ubiquinone
# mitochondrial ATP synthesis coupled electron transport
# intracellular protein transport
# ribosome biogenesis
# protein folding
# mitochondrial respiratory chain complex I assembly
# NADH metabolic process
# Current gene cluster under examination: Louvain 4
# 126 GO terms are enriched in Louvain cluster 4
# 22 MF terms are significantly enriched.
# 32 BP terms are significantly enriched.
# 68 CC terms are significantly enriched.
# mRNA splicing, via spliceosome
# RNA splicing
# mRNA processing
# translation
# protein folding
# positive regulation of establishment of protein localization to telomere
# spliceosomal snRNP assembly
# protein stabilization
# translational initiation
# proteasomal ubiquitin-independent protein catabolic process
# Current gene cluster under examination: Louvain 5
# 131 GO terms are enriched in Louvain cluster 5
# 32 MF terms are significantly enriched.
# 41 BP terms are significantly enriched.
# 57 CC terms are significantly enriched.
# nervous system development
# axon guidance
# axonogenesis
# multicellular organism development
# microtubule-based process
# regulation of microtubule polymerization or depolymerization
# hippocampus development
# positive regulation of transcription by RNA polymerase II
# neuron projection development
# cell differentiation
# Current gene cluster under examination: Louvain 6
# 86 GO terms are enriched in Louvain cluster 6
# 22 MF terms are significantly enriched.
# 27 BP terms are significantly enriched.
# 37 CC terms are significantly enriched.
# lipid metabolic process
# L-serine biosynthetic process
# negative regulation of long-term synaptic potentiation
# oxidation-reduction process
# fatty acid metabolic process
# cellular response to copper ion
# negative regulation of amyloid-beta formation
# negative regulation of amyloid fibril formation
# detoxification of copper ion
# response to oxidative stress
# Current gene cluster under examination: Louvain 7
# 135 GO terms are enriched in Louvain cluster 7
# 19 MF terms are significantly enriched.
# 62 BP terms are significantly enriched.
# 52 CC terms are significantly enriched.
# cell cycle
# cell division
# chromosome segregation
# mitotic cytokinesis
# mitotic sister chromatid segregation
# metaphase plate congression
# nucleosome assembly
# mitotic spindle assembly checkpoint
# mitotic spindle organization
# microtubule-based movement
# Current gene cluster under examination: Louvain 8
# 46 GO terms are enriched in Louvain cluster 8
# 13 MF terms are significantly enriched.
# 13 BP terms are significantly enriched.
# 19 CC terms are significantly enriched.
# translation
# cytoplasmic translation
# ribosomal small subunit assembly
# rRNA processing
# ribosomal small subunit biogenesis
# ribosomal large subunit assembly
# ribosomal large subunit biogenesis
# cellular response to interleukin-4
# maturation of SSU-rRNA from tricistronic rRNA transcript (SSU-rRNA, 5.8S rRNA, LSU-rRNA)
# negative regulation of ubiquitin protein ligase activity
# Current gene cluster under examination: Louvain 9
# 91 GO terms are enriched in Louvain cluster 9
# 20 MF terms are significantly enriched.
# 45 BP terms are significantly enriched.
# 24 CC terms are significantly enriched.
# DNA replication
# DNA repair
# cellular response to DNA damage stimulus
# cell cycle
# DNA replication initiation
# double-strand break repair via break-induced replication
# double-strand break repair via homologous recombination
# regulation of double-strand break repair via homologous recombination
# DNA replication checkpoint
# pre-replicative complex assembly involved in nuclear cell cycle DNA replication
# Current gene cluster under examination: Louvain 10
# 80 GO terms are enriched in Louvain cluster 10
# 14 MF terms are significantly enriched.
# 44 BP terms are significantly enriched.
# 22 CC terms are significantly enriched.
# immune system process
# immune response
# cellular response to interferon-beta
# antigen processing and presentation
# antigen processing and presentation of peptide antigen via MHC class I
# defense response to virus
# innate immune response
# positive regulation of T cell mediated cytotoxicity
# response to bacterium
# antigen processing and presentation of endogenous peptide antigen via MHC class I via ER pathway, TAP-independent
# Current gene cluster under examination: Louvain 11
# 62 GO terms are enriched in Louvain cluster 11
# 9 MF terms are significantly enriched.
# 11 BP terms are significantly enriched.
# 42 CC terms are significantly enriched.
# response to amphetamine
# visual learning
# regulation of long-term neuronal synaptic plasticity
# memory
# ionotropic glutamate receptor signaling pathway
# intracellular signal transduction
# positive regulation of neuron projection development
# regulation of neuronal synaptic plasticity
# positive regulation of long-term synaptic potentiation
# positive regulation of excitatory postsynaptic potential
